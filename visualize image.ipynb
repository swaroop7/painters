# %%
import numpy as np
import PIL
from matplotlib.pyplot import imshow
# %matplotlib inline

# %%
input_file = open('C:\\Users\\swaroop\\Downloads\\painters\\cnn_features\\april9\\train_conv5_1_APRIL8.txt')

random = {}
count = 0

for line in input_file:
    new_line = ''
    print len(random)
    for each_word in line.split():
        words = each_word.strip().split(":")
        if ':' in each_word:
            if words[0] not in random.keys():
                random[int(words[0])] = 0.

print 'part 1 done'

k = 1
for line in input_file:
    filename = 'C:\\Users\\swaroop\\Downloads\\painters\\cnn_features\\april9\\image_'+str(k)+'.txt'
    k += 1
    output_file = open(filename,'w')
    for each_word in line.split():
        words = each_word.strip().split(":")
        if ':' in each_word:
            random[int(words[0])] = round(float(words[1]), 4)
            
    for i in xrange(1,103530):
        count += 1
        if i in random.keys():
            output_file.write(str(random[i])+' ')
            random[int(words[0])] = 0.
        else:
            output_file.write(str(0.)+' ')
        if count == 512:
            output_file.write('\n')
            count = 0
    output_file.close()
    
input_file.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-8a9634a9d383> in <module>()
#      31             random[int(words[0])] = 0.
#      32         else:
# ---> 33             output_file.write(str(0.)+' ')
#      34         if count == 512:
#      35             output_file.write('\n')
#
# KeyboardInterrupt:

# %%
#pil_im = Image.open('data/empire.jpg', 'r')
#imshow(np.asarray(pil_im)
try:
    arr = np.loadtxt('C:\\Users\\swaroop\\Downloads\\painters\\cnn_features\\april9\\images\\image_31.txt')
    img = PIL.Image.fromarray(arr)
    imshow(img)
except:
    arr = np.genfromtxt('C:\\Users\\swaroop\\Downloads\\painters\\cnn_features\\april9\\images\\image_31.txt', skip_header = 1, skip_footer = 1)
    img = PIL.Image.fromarray(arr)
    imshow(img)

# %%
# Out:
# 201
